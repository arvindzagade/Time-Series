# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f_birth = pd.read_csv('female_birth.csv',index_col='Date',parse_dates=True)

# %%
f_birth.head()
# Out:
#             Female_Births
# Date
# 1959-01-01             35
# 1959-02-01             32
# 1959-03-01             30
# 1959-04-01             31
# 1959-05-01             44

# %%
f_birth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 1959-01-01 to 1959-12-31
# Data columns (total 1 columns):
# Female_Births    365 non-null int64
# dtypes: int64(1)
# memory usage: 5.7 KB

# %%
f_birth.isna().sum()
# Out:
# Female_Births    0
# dtype: int64

# %%
f_birth.describe()
# Out:
#        Female_Births
# count     365.000000
# mean       41.980822
# std         7.348257
# min        23.000000
# 25%        37.000000
# 50%        42.000000
# 75%        46.000000
# max        73.000000

# %%
type(f_birth)
# Out:
# pandas.core.frame.DataFrame

# %%
series_value = f_birth.values

# %%
series_value
# Out:
# array([[35],
#        [32],
#        [30],
#        [31],
#        [44],
#        [29],
#        [45],
#        [43],
#        [38],
#        [27],
#        [38],
#        [33],
#        [55],
#        [47],
#        [45],
#        [37],
#        [50],
#        [43],
#        [41],
#        [52],
#        [34],
#        [53],
#        [39],
#        [32],
#        [37],
#        [43],
#        [39],
#        [35],
#        [44],
#        [38],
#        [24],
#        [23],
#        [31],
#        [44],
#        [38],
#        [50],
#        [38],
#        [51],
#        [31],
#        [31],
#        [51],
#        [36],
#        [45],
#        [51],
#        [34],
#        [52],
#        [47],
#        [45],
#        [46],
#        [39],
#        [48],
#        [37],
#        [35],
#        [52],
#        [42],
#        [45],
#        [39],
#        [37],
#        [30],
#        [35],
#        [28],
#        [45],
#        [34],
#        [36],
#        [50],
#        [44],
# ...

# %%
type(series_value)
# Out:
# numpy.ndarray

# %%
f_birth.size
# Out:
# 365

# %%
f_birth.plot(figsize=(12,5))

# %%
## Smoothing a Series

# %%
f_birth_mean = f_birth.rolling(window=30).mean()

# %%
f_birth.plot()
f_birth_mean.plot()
